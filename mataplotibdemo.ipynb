# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.array([10,25])
y=np.array([50,350])

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,'x')
plt.show()

# %%
x1=np.array([2,13,25,67])
y1=np.array([10,20,85,52])
plt.plot(x1,y1)
plt.show()

# %%
plt.plot(y1,marker='o')
plt.show()

# %%
plt.plot(y1,marker='*')
plt.show()

# %%
plt.plot(y1,marker='.')
plt.show()

# %%
plt.plot(y1,marker=',')
plt.show()

# %%
plt.plot(y1,marker='x')
plt.show()

# %%
plt.plot(y1,marker='X')
plt.show()

# %%
plt.plot(y1,marker='+')
plt.show()

# %%
plt.plot(y1,marker='p')
plt.show()

# %%
plt.plot(y1,marker='s')
plt.show()

# %%
plt.plot(y1,marker='D')
plt.show()

# %%
plt.plot(y1,marker='d')
plt.show()

# %%
plt.plot(y1,marker='P')
plt.show()

# %%
plt.plot(y1,marker='H')
plt.show()

# %%
plt.plot(y1,marker='h')
plt.show()

# %%
plt.plot(y1,marker='v')
plt.show()

# %%
plt.plot(y1,marker='^')
plt.show()

# %%
plt.plot(y1,marker='<')
plt.show()

# %%
plt.plot(y1,marker='>')
plt.show()

# %%
plt.plot(y1,marker='1')
plt.show()

# %%
plt.plot(y1,marker='2')
plt.show()

# %%
plt.plot(x1,y1,marker='*',ms=10,mec='r',mfc='b')
plt.show()

# %%
plt.plot(x1,y1,marker='*',ms=10,mec='r',mfc='b',ls=':')
plt.show()

# %%
plt.plot(x1,y1,marker='*',ms=10,mec='r',mfc='b',ls='-')
plt.show()

# %%
plt.plot(x1,y1,marker='*',ms=10,mec='r',mfc='b',ls='--')
plt.show()

# %%
plt.plot(x1,y1,linestyle='dotted',color='m',linewidth='15')
plt.show()

# %%
plt.plot(x,y,x1,y1)
plt.show()

# %%
font={'color':'green','size':'25'}
plt.title("line chart",fontdict=font,loc="left")
plt.xlabel("number1")
plt.ylabel("number2")
plt.plot(x1,y1)
plt.grid(axis='y',color='red',linestyle='--',linewidth='0.5')

# %%
plt.subplot(1,2,1)#one row,2 columns=>subplot(2,1,1)->2row, 1 column=> can have 2 rows 3 columns to display 6 plots in one figure.
plt.title("p1")
plt.plot(x,y)
plt.subplot(1,2,2)
plt.title("p2")
plt.plot(x1,y1)
plt.suptitle("SuperTitle")
# Out:
# Text(0.5, 0.98, 'SuperTitle')

# %%
sizes=np.array([10,50])
plt.scatter(x1,y1,color='red')
plt.scatter(x,y,color='green',s=sizes, alpha=0.5)

# %%
plt.bar(x1,y1)
# Out:
# <BarContainer object of 4 artists>

# %%
x1=np.array([2,13,25,67])
y1=np.array([10,20,85,52])
plt.plot(x1,y1)

# %%
plt.barh(x1,y1,height=10)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(x1,y1,color='m',width=11)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.hist(x1)
# Out:
# (array([1., 1., 0., 1., 0., 0., 0., 0., 0., 1.]),
#  array([ 2. ,  8.5, 15. , 21.5, 28. , 34.5, 41. , 47.5, 54. , 60.5, 67. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.pie(x1)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f1caa675d30>,
# ...
#  [Text(1.0981040361812209, 0.06455637631180881, ''),
#   Text(0.9657984495240577, 0.5265295384847144, ''),
#   Text(-0.04842946277668594, 1.0989333861227266, ''),
#   Text(-0.4246786391308206, -1.0147157500827484, '')])

# %%
track_stud=np.array([20,50,40,10,10])
track_name=["Data","Mobile","Web","IoT","CyberSecurity"]
ex=[0.2,0,0,0,0]
col=["Red","Pink",'m','g','b']
plt.pie(track_stud,labels=track_name,startangle=90,explode=ex,shadow=True,colors=col)
plt.legend(title="Tracks")
plt.show()
